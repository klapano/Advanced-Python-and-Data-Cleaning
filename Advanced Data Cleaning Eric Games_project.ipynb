# %%
import pandas as pd
from datetime import datetime
from datetime import date
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('igdb_dataset.csv', low_memory = False)
df
# Out:
#              id                               name platforms  \
# 0          70.0    "TerraNova:StrikeForceCentauri"        13
# 1       40104.0                      "DogouSouken"        52
# 2       51663.0           "TheFiremen2:Pete&Danny"       NaN
# 3       86911.0   "Baccarat-BestCasinoBettingGame"        14
# 4       68841.0                         "Captivus"         6
# ...         ...                                ...       ...
# 135058  29532.0             "TheMoonstoneEquation"         6
# 135059  89201.0                     "MagicMermaid"        39
# 135060  46274.0  "JoeMontanaII:SportstalkFootball"        29
# 135061  18879.0            "Horde:TheNorthernWind"         6
# 135062  96616.0       "TimeTenshiParadox:Episode2"       NaN
#
#         first_release_date  category    genres    themes player_perspectives  \
# 0             8.259840e+08       0.0   5,13,15      1,18                   1
# ...

# %%
df['first_release_date'] = pd.to_datetime(df['first_release_date'], unit='s')

# %%
df
# Out:
#              id                               name platforms  \
# 0          70.0    "TerraNova:StrikeForceCentauri"        13
# 1       40104.0                      "DogouSouken"        52
# 2       51663.0           "TheFiremen2:Pete&Danny"       NaN
# 3       86911.0   "Baccarat-BestCasinoBettingGame"        14
# 4       68841.0                         "Captivus"         6
# ...         ...                                ...       ...
# 135058  29532.0             "TheMoonstoneEquation"         6
# 135059  89201.0                     "MagicMermaid"        39
# 135060  46274.0  "JoeMontanaII:SportstalkFootball"        29
# 135061  18879.0            "Horde:TheNorthernWind"         6
# 135062  96616.0       "TimeTenshiParadox:Episode2"       NaN
#
#        first_release_date  category    genres    themes player_perspectives  \
# 0              1996-03-05       0.0   5,13,15      1,18                   1
# 1              1987-01-01       0.0         5       NaN                 NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135063 entries, 0 to 135062
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       135062 non-null  float64
#  1   name                     135061 non-null  object
#  2   platforms                75337 non-null   object
#  3   first_release_date       73294 non-null   datetime64[ns]
#  4   category                 135062 non-null  float64
#  5   genres                   92472 non-null   object
#  6   themes                   59622 non-null   object
#  7   player_perspectives      36100 non-null   object
#  8   rating                   31303 non-null   object
#  9   rating_count             31300 non-null   float64
#  10  similar_games            99347 non-null   object
#  11  total_rating             31300 non-null   float64
#  12  total_rating_count       31300 non-null   float64
# ...

# %%
df.head()
# Out:
#         id                              name platforms first_release_date  \
# 0     70.0   "TerraNova:StrikeForceCentauri"        13         1996-03-05
# 1  40104.0                     "DogouSouken"        52         1987-01-01
# 2  51663.0          "TheFiremen2:Pete&Danny"       NaN                NaT
# 3  86911.0  "Baccarat-BestCasinoBettingGame"        14         2013-10-17
# 4  68841.0                        "Captivus"         6         2017-10-03
#
#    category   genres themes player_perspectives rating  rating_count  \
# 0       0.0  5,13,15   1,18                   1   70.0           2.0
# 1       0.0        5    NaN                 NaN    NaN           NaN
# 2       0.0      NaN    NaN                 NaN    NaN           NaN
# 3       0.0      NaN    NaN                 NaN    NaN           NaN
# 4       0.0    15,16     18                 NaN    NaN           NaN
#
#                                        similar_games  total_rating  \
# ...

# %%
df.describe()
# Out:
#                   id       category  rating_count  total_rating  \
# count  135062.000000  135062.000000  31300.000000  31300.000000
# mean    70664.254972       0.081777     13.901086     66.132921
# std     40694.453733       0.534446     75.022597     14.886746
# min         1.000000       0.000000      0.000000      0.000000
# 25%     35540.250000       0.000000      0.000000     57.500000
# 50%     70690.500000       0.000000      1.000000     70.000000
# 75%    105830.750000       0.000000      5.000000     77.500000
# max    141114.000000       7.000000   2783.000000    100.000000
#
#        total_rating_count  aggregated_rating  aggregated_rating_count
# count         31300.00000       13124.000000             13124.000000
# mean             15.26885          68.438922                 3.680204
# std              76.43429          16.351182                 4.136703
# min               0.00000           0.000000                 0.000000
# ...

# %%
df.tail()
# Out:
#              id                               name platforms  \
# 135058  29532.0             "TheMoonstoneEquation"         6
# 135059  89201.0                     "MagicMermaid"        39
# 135060  46274.0  "JoeMontanaII:SportstalkFootball"        29
# 135061  18879.0            "Horde:TheNorthernWind"         6
# 135062  96616.0       "TimeTenshiParadox:Episode2"       NaN
#
#        first_release_date  category    genres    themes player_perspectives  \
# 135058         2018-06-30       0.0   8,31,32       NaN                   4
# 135059         2017-05-30       0.0        12       NaN                 NaN
# 135060         1991-05-01       0.0        14       NaN                 NaN
# 135061         1999-11-03       0.0     11,32  17,22,38                   3
# 135062                NaT       0.0  13,31,32       NaN                 NaN
#
#                   rating  rating_count  \
# 135058              70.0           0.0
# 135059              90.0           0.0
# ...

# %%
df.describe()
# Out:
#                   id       category  rating_count  total_rating  \
# count  135062.000000  135062.000000  31300.000000  31300.000000
# mean    70664.254972       0.081777     13.901086     66.132921
# std     40694.453733       0.534446     75.022597     14.886746
# min         1.000000       0.000000      0.000000      0.000000
# 25%     35540.250000       0.000000      0.000000     57.500000
# 50%     70690.500000       0.000000      1.000000     70.000000
# 75%    105830.750000       0.000000      5.000000     77.500000
# max    141114.000000       7.000000   2783.000000    100.000000
#
#        total_rating_count  aggregated_rating  aggregated_rating_count
# count         31300.00000       13124.000000             13124.000000
# mean             15.26885          68.438922                 3.680204
# std              76.43429          16.351182                 4.136703
# min               0.00000           0.000000                 0.000000
# ...

# %%
df.shape
# Out:
# (135063, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135063 entries, 0 to 135062
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       135062 non-null  float64
#  1   name                     135061 non-null  object
#  2   platforms                75337 non-null   object
#  3   first_release_date       73294 non-null   datetime64[ns]
#  4   category                 135062 non-null  float64
#  5   genres                   92472 non-null   object
#  6   themes                   59622 non-null   object
#  7   player_perspectives      36100 non-null   object
#  8   rating                   31303 non-null   object
#  9   rating_count             31300 non-null   float64
#  10  similar_games            99347 non-null   object
#  11  total_rating             31300 non-null   float64
#  12  total_rating_count       31300 non-null   float64
# ...

# %%
df.isna().sum()
# Out:
# id                              1
# name                            2
# platforms                   59726
# first_release_date          61769
# category                        1
# genres                      42591
# themes                      75441
# player_perspectives         98963
# rating                     103760
# rating_count               103763
# similar_games               35716
# total_rating               103763
# total_rating_count         103763
# url                             2
# aggregated_rating          121939
# aggregated_rating_count    121939
# dtype: int64

# %% [markdown]
# # 1)What’s the first game ever released and when (not created)?

# %%
df.dropna()
# Out:
#              id                                name               platforms  \
# 0          70.0     "TerraNova:StrikeForceCentauri"                      13
# 41      14543.0            "BioShock2:Minerva'sDen"                  6,9,12
# 124     76770.0           "BridgeConstructorPortal"  3,6,14,34,39,48,49,130
# 326      9637.0             "OrcsMustDie!Unchained"                 6,45,48
# 386      2129.0                    "MarkoftheNinja"               3,6,12,14
# ...         ...                                 ...                     ...
# 134889     80.0                        "TheWitcher"                    6,14
# 134893    521.0                             "Fable"                      11
# 134898  17583.0                       "SpellForce3"                       6
# 134899  12527.0             "Yakuza6:TheSongofLife"                      48
# 134926  25741.0  "AshesoftheSingularity:Escalation"                       6
#
# ...

# %%
df.sort_values('first_release_date', ascending = True).head()
# Out:
#              id                             name platforms first_release_date  \
# 30947   11321.0  "CathodeRayTubeAmusementDevice"       100         1947-12-31
# 19539   11322.0                            "Nim"       101         1951-12-31
# 65608   11323.0                            "OXO"       102         1952-12-31
# 133339   6763.0                   "TennisforTwo"        85         1958-10-18
# 65083   11301.0                      "Spacewar!"        95         1962-04-30
#
#         category   genres themes player_perspectives rating  rating_count  \
# 30947        0.0        2     39                 NaN    NaN           NaN
# 19539        0.0    15,30     34                 NaN    NaN           NaN
# 65608        0.0     9,15     34                 NaN    NaN           NaN
# 133339       0.0    14,33      1                   4   85.0           4.0
# 65083        0.0  5,13,30   1,18                   3    NaN           NaN
#
# ...

# %%
df.sort_values('first_release_date', ascending = True).head(1)
# Out:
#             id                             name platforms first_release_date  \
# 30947  11321.0  "CathodeRayTubeAmusementDevice"       100         1947-12-31
#
#        category genres themes player_perspectives rating  rating_count  \
# 30947       0.0      2     39                 NaN    NaN           NaN
#
#                                            similar_games  total_rating  \
# 30947  236,9760,25222,27725,34024,55029,106805,112078...           NaN
#
#        total_rating_count                                                url  \
# 30947                 NaN  "https://www.igdb.com/games/cathode-ray-tube-a...
#
#        aggregated_rating  aggregated_rating_count
# 30947                NaN                      NaN

# %%
df.sort_values('first_release_date', ascending = True).head(1)['name']
# Out:
# 30947    "CathodeRayTubeAmusementDevice"
# Name: name, dtype: object

# %%
df.sort_values('first_release_date', ascending = True).head(1)['first_release_date']
# Out:
# 30947   1947-12-31
# Name: first_release_date, dtype: datetime64[ns]

# %% [markdown]
# # 2)Which are the top 5 games of all time? (tip: many games score 100 rating and have a few reviews, other games score a bit lower but much higher reviews...)

# %%
df
# Out:
#              id                               name platforms  \
# 0          70.0    "TerraNova:StrikeForceCentauri"        13
# 1       40104.0                      "DogouSouken"        52
# 2       51663.0           "TheFiremen2:Pete&Danny"       NaN
# 3       86911.0   "Baccarat-BestCasinoBettingGame"        14
# 4       68841.0                         "Captivus"         6
# ...         ...                                ...       ...
# 135058  29532.0             "TheMoonstoneEquation"         6
# 135059  89201.0                     "MagicMermaid"        39
# 135060  46274.0  "JoeMontanaII:SportstalkFootball"        29
# 135061  18879.0            "Horde:TheNorthernWind"         6
# 135062  96616.0       "TimeTenshiParadox:Episode2"       NaN
#
#        first_release_date  category    genres    themes player_perspectives  \
# 0              1996-03-05       0.0   5,13,15      1,18                   1
# 1              1987-01-01       0.0         5       NaN                 NaN
# ...

# %%
df = df.dropna()
df
# Out:
#              id                                name               platforms  \
# 0          70.0     "TerraNova:StrikeForceCentauri"                      13
# 41      14543.0            "BioShock2:Minerva'sDen"                  6,9,12
# 124     76770.0           "BridgeConstructorPortal"  3,6,14,34,39,48,49,130
# 326      9637.0             "OrcsMustDie!Unchained"                 6,45,48
# 386      2129.0                    "MarkoftheNinja"               3,6,12,14
# ...         ...                                 ...                     ...
# 134889     80.0                        "TheWitcher"                    6,14
# 134893    521.0                             "Fable"                      11
# 134898  17583.0                       "SpellForce3"                       6
# 134899  12527.0             "Yakuza6:TheSongofLife"                      48
# 134926  25741.0  "AshesoftheSingularity:Escalation"                       6
#
# ...

# %%
df[df['id']==5024.0]
# Out:
#            id             name platforms first_release_date  category genres  \
# 43040  5024.0  "TheMunchables"         5         2009-05-27       0.0      8
#
#       themes player_perspectives rating  rating_count  \
# 43040   1,27                   2  100.0           4.0
#
#                                            similar_games  total_rating  \
# 43040  19150,19164,24426,54775,55199,56033,76960,8091...         100.0
#
#        total_rating_count                                          url  \
# 43040                 4.0  "https://www.igdb.com/games/the-munchables"
#
#        aggregated_rating  aggregated_rating_count
# 43040              100.0                      4.0

# %%
df['rating']= pd.to_numeric(df['rating'], errors ='ignore')
df['rating']
# Out:
# C:\Users\klaud\AppData\Local\Temp\ipykernel_33732\4192123988.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rating']= pd.to_numeric(df['rating'], errors ='ignore')
# 0         70.000000
# 41        85.370157
# 124       71.205547
# 326       75.090200
# 386       84.777598
#             ...
# 134889    83.037758
# 134893    86.507793
# 134898    38.905077
# 134899    84.942803
# 134926    78.095238
# Name: rating, Length: 7960, dtype: float64

# %%
df.groupby(['id','name']).sum().sort_values('weighted_score', ascending = False).head()
# Out:
#                                   category     rating  rating_count  \
# id     name
# 1020.0 "GrandTheftAutoV"               0.0  91.007003        2783.0
# 1942.0 "TheWitcher3:WildHunt"          0.0  95.708657        2468.0
# 72.0   "Portal2"                       0.0  91.331534        2116.0
# 472.0  "TheElderScrollsV:Skyrim"       0.0  87.714979        2184.0
# 1009.0 "TheLastofUs"                   0.0  94.494275        1835.0
#
#                                   total_rating  total_rating_count  \
# id     name
# 1020.0 "GrandTheftAutoV"             93.423502              2817.0
# 1942.0 "TheWitcher3:WildHunt"        93.714329              2494.0
# 72.0   "Portal2"                     91.887989              2129.0
# 472.0  "TheElderScrollsV:Skyrim"     91.913045              2196.0
# 1009.0 "TheLastofUs"                 93.016368              1851.0
#
#                                   aggregated_rating  aggregated_rating_count  \
# id     name
# ...

# %%
#df['year'] = df['first_release_date'].dt.year
#df['month'] = df['first_release_date'].dt.month

# %%
#####df['rating'] = pd.to_numeric(df['rating'], error = 'ignore')

# %%
df[df['rating'].str.contains('.*[a-zA-Z].*') == True]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 df[df['rating'].str.contains('.*[a-zA-Z].*') == True]
#
# File ~\miniconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# File ~\miniconda3\lib\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# --> 182 accessor_obj = self._accessor(obj)
# ...

# %% [markdown]
# # 3)Do game ratings vary from year to year?

# %%
df['year'] = pd.DatetimeIndex(df['first_release_date']).year
df['year']

# %%
df = df.dropna()
df

# %%
df['avg_total_rating'] = df['total_rating'].mean()
df['avg_total_rating']

# %%
df.groupby('year').count()['avg_total_rating'].plot.bar(rot = 45, figsize=(15,5))
None

# %%
df.groupby('year').count()['rating'].plot.bar(rot = 45, figsize=(15,5))
None

# %%
df.groupby('year')['rating'].count().plot.bar(rot = 45, figsize=(15,5))
None

# %%
result = df.groupby("year")["rating_count"].unique()
result.hist(by = df["year"])

# %% [markdown]
# # 4)In which year the most games were release

# %%
df.groupby('year').count().sort_values(by = 'rating_count', ascending = False).head()# and without by = 'id' it still works

# %% [markdown]
# # 5)In the last 5 years, which month were released the most games per year, can you guess why?

# %%
df['month'] = pd.DatetimeIndex(df['first_release_date']).month
df['month']

# %%
df['year'] = pd.DatetimeIndex(df['first_release_date']).year
df['year']

# %%
df

# %%
diff = pd.date_range(start='1/1/2016', end='1/1/2020')
diff

# %%
df['Month_Year'] = df['first_release_date'].dt.to_period('M')
df

# %%
DF2 = df[(df['Month_Year'] >= '2016-01') & (df['Month_Year'] =< '2020-01')]
DF2

# %%
DF2.groupby(['year', 'month']).count().sort_values('id', ascending = False)

# %%
DF2.groupby(['year', 'month']).count().sort_values('id', ascending = False).plot.bar(rot = 45, figsize=(15,5))
None

# %%
df["weighted_score"] = df["rating"] * df["rating_count"]
df["weighted_score"]
# Out:
# C:\Users\klaud\AppData\Local\Temp\ipykernel_33732\1366953013.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["weighted_score"] = df["rating"] * df["rating_count"]
# 0           140.000000
# 41         2731.845011
# 124        1352.905401
# 326         825.992195
# 386       18227.183554
#               ...
# 134889    36702.689204
# 134893    14187.278052
# 134898      505.765995
# 134899     1359.084845
# 134926      390.476190
# Name: weighted_score, Length: 7960, dtype: float64

# %%
df
# Out:
#              id                                name               platforms  \
# 0          70.0     "TerraNova:StrikeForceCentauri"                      13
# 41      14543.0            "BioShock2:Minerva'sDen"                  6,9,12
# 124     76770.0           "BridgeConstructorPortal"  3,6,14,34,39,48,49,130
# 326      9637.0             "OrcsMustDie!Unchained"                 6,45,48
# 386      2129.0                    "MarkoftheNinja"               3,6,12,14
# ...         ...                                 ...                     ...
# 134889     80.0                        "TheWitcher"                    6,14
# 134893    521.0                             "Fable"                      11
# 134898  17583.0                       "SpellForce3"                       6
# 134899  12527.0             "Yakuza6:TheSongofLife"                      48
# 134926  25741.0  "AshesoftheSingularity:Escalation"                       6
#
# ...

# %%
df["normalized_weighted_score"] = (df["weighted_score"] - df["weighted_score"].min()) / (df["weighted_score"].max() - df["weighted_score"].min()) * 100
# Out:
# C:\Users\klaud\AppData\Local\Temp\ipykernel_33732\2852256536.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["normalized_weighted_score"] = (df["weighted_score"] - df["weighted_score"].min()) / (df["weighted_score"].max() - df["weighted_score"].min()) * 100

# %%
df["normalized_weighted_score"]
# Out:
# 0          0.055276
# 41         1.078619
# 124        0.534170
# 326        0.326128
# 386        7.196669
#             ...
# 134889    14.491384
# 134893     5.601587
# 134898     0.199692
# 134899     0.536610
# 134926     0.154172
# Name: normalized_weighted_score, Length: 7960, dtype: float64

# %%
df["weighted_score"]
# Out:
# 0           140.000000
# 41         2731.845011
# 124        1352.905401
# 326         825.992195
# 386       18227.183554
#               ...
# 134889    36702.689204
# 134893    14187.278052
# 134898      505.765995
# 134899     1359.084845
# 134926      390.476190
# Name: weighted_score, Length: 7960, dtype: float64

# %%
df["weighted_score"].min()
# Out:
# 0.0

# %%
df["weighted_score"].max()
# Out:
# 253272.49045030464

# %%
#x κανονικοποιημένο = ( x - x ελάχιστο ) / ( x μέγιστο - x ελάχιστο )
#Τι είναι ο τύπος κανονικοποίησης;
#Στα στατιστικά στοιχεία, ο όρος «ομαλοποίηση» αναφέρεται στην κλιμάκωση του συνόλου δεδομένων έτσι ώστε τα κανονικοποιημένα δεδομένα να κυμαίνονται μεταξύ 0 και 1.
