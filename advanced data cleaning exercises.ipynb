# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
import re

# %%
df = pd.read_csv('igbd_dataset_v1.csv', skipinitialspace=False, low_memory = False)
df
# Out:
#               id                                 name     platforms  \
# 0         1020.0                      GrandTheftAutoV  6,9,12,48,49
# 1         1942.0                 TheWitcher3:WildHunt       6,48,49
# 2           72.0                              Portal2   3,6,9,12,14
# 3          472.0              TheElderScrollsV:Skyrim        6,9,12
# 4         1009.0                          TheLastofUs             9
# ...          ...                                  ...           ...
# 122397   36795.0                  SuperDoomed'nDamned           NaN
# 122398  114314.0                         DestleStrike           NaN
# 122399  115593.0                            NextStop3           NaN
# 122400  115038.0  \u5e7d\u94c3\u5170-lilyofthehollow-           NaN
# 122401   76632.0                            [accuwar]            82
#
#        first_release_date  category      genres      themes  \
# 0              2013-09-17       0.0  5,10,14,31  1,27,33,38
# ...

# %%
genres = {
    2:"Point-and-click",
    4:"Fighting",
    5:"Shooter",
    7:"Music",
    8:"Platform",
    9:"Puzzle",
    10:"Racing",
    11:"Real Time Strategy (RTS)",
    12:"Role-playing (RPG)",
    13:"Simulator",
    14:"Sport",
    15:"Strategy",
    16:"Turn-based strategy (TBS)",
    24:"Tactical",
    26:"Quiz/Trivia",
    25:"Hack and slash/Beat 'em up",
    30:"Pinball",
    31:"Adventure",
    33:"Arcade",
    34:"Visual Novel",
    32:"Indie",
    35:"Card & Board Game",
    36:"MOBA",
}

#df['State'] = df.apply(lambda x: state_dict[x['City']] if x['City'] in state_dict else x['State'], axis=1)
#df['continent'] = df.index.to_series().map(ContinentDict)
#pd.Series(df.index.values).map(ContinentDict) oxi giati den kanei.


#generates NaN because you're constructing a Series from the numpy values so the index returned is the auto-generated RangeIndex so when it tries to align against your df, it fails so all rows become NaN



df['genres'] = df.index.to_series().map(genres)
df['genres']
# Out:
# 0                     NaN
# 1                     NaN
# 2         Point-and-click
# 3                     NaN
# 4                Fighting
#                ...
# 122397                NaN
# 122398                NaN
# 122399                NaN
# 122400                NaN
# 122401                NaN
# Name: genres, Length: 122402, dtype: object

# %%
themes = {
    17:"Fantasy",
    20:"Thriller",
    18:"Science fiction",
    1 :"Action",
    19:"Horror",
    21:"Survival",
    22:"Historical",
    23:"Stealth",
    28:"Business",
    27:"Comedy",
    31:"Drama",
    32:"Non-fiction",
    34:"Educational",
    33:"Sandbox",
    35:"Kids",
    38:"Open world",
    39:"Warfare",
    41:"4X (explore, expand, exploit, and exterminate)",
    42:"Erotic",
    43:"Mystery",
    40:"Party",
    44:"Romance"  
}


df['themes'] = df.index.to_series().map(themes)
df['themes']
# Out:
# 0            NaN
# 1         Action
# 2            NaN
# 3            NaN
# 4            NaN
#            ...
# 122397       NaN
# 122398       NaN
# 122399       NaN
# 122400       NaN
# 122401       NaN
# Name: themes, Length: 122402, dtype: object

# %%
perspectives = {
    1:"First person",
    2:"Third person",
    3:"Bird view",
    4:"Side view",
    5:"Text",
    6:"Auditory",
    7:"Virtual Reality"
}


df['player_perspectives'] = df.index.to_series().map(perspectives)
df
# Out:
#               id                                 name     platforms  \
# 0         1020.0                      GrandTheftAutoV  6,9,12,48,49
# 1         1942.0                 TheWitcher3:WildHunt       6,48,49
# 2           72.0                              Portal2   3,6,9,12,14
# 3          472.0              TheElderScrollsV:Skyrim        6,9,12
# 4         1009.0                          TheLastofUs             9
# ...          ...                                  ...           ...
# 122397   36795.0                  SuperDoomed'nDamned           NaN
# 122398  114314.0                         DestleStrike           NaN
# 122399  115593.0                            NextStop3           NaN
# 122400  115038.0  \u5e7d\u94c3\u5170-lilyofthehollow-           NaN
# 122401   76632.0                            [accuwar]            82
#
#        first_release_date  category           genres  themes  \
# 0              2013-09-17       0.0              NaN     NaN
# ...

# %%
platforms = {
0 : 'missing',  
1 : 'missing',
2 : 'missing',
3 : 'Linux',
4 : 'Nintendo 64',
5 : 'Wii',
6 : 'PC',
7 : 'PlayStation',
8 : 'PlayStation 2',
9 : 'PlayStation 3',
11 : 'Xbox',
12 : 'Xbox 360',
13 : 'PC DOS',
14 : 'Mac',
15 : 'Commodore C64/128',
16 : 'Amiga',
18 : 'Nintendo Entertainment System (NES)',
19 : 'Super Nintendo Entertainment System (SNES)',
20 : 'Nintendo DS',
21 : 'Nintendo GameCube',
22 : 'Game Boy Color',
23 : 'Dreamcast',
24 : 'Game Boy Advance',
25 : 'Amstrad CPC',
26 : 'ZX Spectrum',
27 : 'MSX',
29 : 'Sega Mega Drive/Genesis',
30 : 'Sega 32X',
32 : 'Sega Saturn',
33 : 'Game Boy',
34 : 'Android',
35 : 'Sega Game Gear',
36 : 'Xbox Live Arcade',
37 : 'Nintendo 3DS',
38 : 'PlayStation Portable',
39 : 'iOS',
41 : 'Wii U',
42 : 'N-Gage',
44 : 'Tapwave Zodiac',
45 : 'PlayStation Network',
46 : 'PlayStation Vita',
47 : 'Virtual Console (Nintendo)',
48 : 'PlayStation 4',
49 : 'Xbox One',
50 : '3DO Interactive Multiplayer',
51 : 'Family Computer Disk System',
52 : 'Arcade',
53 : 'MSX2',
55 : 'Mobile',
56 : 'WiiWare',
57 : 'WonderSwan',
58 : 'Super Famicom',
59 : 'Atari 2600',
60 : 'Atari 7800',
61 : 'Atari Lynx',
62 : 'Atari Jaguar',
63 : 'Atari ST/STE',
64 : 'Sega Master System',
65 : 'Atari 8-bit',
66 : 'Atari 5200',
67 : 'Intellivision',
68 : 'ColecoVision',
69 : 'BBC Microcomputer System',
70 : 'Vectrex',
71 : 'Commodore VIC-20',
72 : 'Ouya',
73 : 'BlackBerry OS',
74 : 'Windows Phone',
75 : 'Apple II',
77 : 'Sharp X1',
78 : 'Sega CD',
79 : 'Neo Geo MVS',
80 : 'Neo Geo AES',
82 : 'Web browser',
84 : 'SG-1000',
85 : 'Donner Model 30',
86 : 'TurboGrafx-16/PC Engine',
87 : 'Virtual Boy',
88 : 'Odyssey',
89 : 'Microvision',
90 : 'Commodore PET',
91 : 'Bally Astrocade',
92 : 'SteamOS',
93 : 'Commodore 16',
94 : 'Commodore Plus/4',
95 : 'PDP-1',
96 : 'PDP-10',
97 : 'PDP-8',
98 : 'DEC GT40',
99 : 'Family Computer (FAMICOM)',
100 : 'Analogue electronics',
101 : 'Ferranti Nimrod Computer',
102 : 'EDSAC',
103 : 'PDP-7',
104 : 'HP 2100',
105 : 'HP 3000',
106 : 'SDS Sigma 7',
107 : 'Call-A-Computer time-shared mainframe computer system',
108 : 'PDP-11',
109 : 'CDC Cyber 70',
110 : 'PLATO',
111 : 'Imlac PDS-1',
112 : 'Microcomputer',
113 : 'OnLive Game System',
114 : 'Amiga CD32',
115 : 'Apple IIGS',
116 : 'Acorn Archimedes',
117 : 'Philips CD-i',
118 : 'FM Towns',
119 : 'Neo Geo Pocket',
120 : 'Neo Geo Pocket Color',
121 : 'Sharp X68000',
122 : 'Nuon',
123 : 'WonderSwan Color',
124 : 'SwanCrystal',
125 : 'PC-8801',
126 : 'TRS-80',
127 : 'Fairchild Channel F',
128 : 'PC Engine SuperGrafx',
129 : 'Texas Instruments TI-99',
130 : 'Nintendo Switch',
131 : 'Nintendo PlayStation',
132 : 'Amazon Fire TV',
133 : 'Philips Videopac G7000',
134 : 'Acorn Electron',
135 : 'Hyper Neo Geo 64',
136 : 'Neo Geo CD',
137 : 'New Nintendo 3DS',
138 : 'VC 4000',
139 : '1292 Advanced Programmable Video System',
140 : 'AY-3-8500',
141 : 'AY-3-8610',
142 : 'PC-50X Family',
143 : 'AY-3-8760',
144 : 'AY-3-8710',
145 : 'AY-3-8603',
146 : 'AY-3-8605',
147 : 'AY-3-8606',
148 : 'AY-3-8607',
149 : 'PC-98',
150 : 'Turbografx-16/PC Engine CD',
151 : 'TRS-80 Color Computer',
152 : 'FM-7',
153 : 'Dragon 32/64',
154 : 'Amstrad PCW',
155 : 'Tatung Einstein',
156 : 'Thomson MO5',
157 : 'NEC PC-6000 Series',
158 : 'Commodore CDTV',
159 : 'Nintendo DSi',
160 : 'Nintendo eShop',
161 : 'Windows Mixed Reality',
162 : 'Oculus VR',
163 : 'SteamVR',
164 : 'Daydream',
165 : 'PlayStation VR',
166 : 'PokĂŠmon mini',
}



#df['State'] = df.apply(lambda x: state_dict[x['City']] if x['City'] in state_dict else x['State'], axis=1)


#f['platforms'] = df.index.to_series().map(platforms)
#df['platforms']

# %%
df['platforms'] = df['platforms'].map(platforms)
df['platforms']
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 122397    NaN
# 122398    NaN
# 122399    NaN
# 122400    NaN
# 122401    NaN
# Name: platforms, Length: 122402, dtype: object

# %%
categories = {
    0:'Main Game',
    1:'DLC Addon',
    2:'Expansion',
    3:'Bundle',
    4:'Standalone Expansion',
    5:'Mod',
    6:'Episode',
    7:'Season'
}


#df['category'] = df.index.to_series().map(categories)
#df['category']

#df['category'] = df['category'].map(categories)
#df['category']

# %%
df['category'] = df['category'].map(categories)
df['category']
# Out:
# 0         Main Game
# 1         Main Game
# 2         Main Game
# 3         Main Game
# 4         Main Game
#             ...
# 122397    Main Game
# 122398    Main Game
# 122399    Main Game
# 122400    Main Game
# 122401    Main Game
# Name: category, Length: 122402, dtype: object

# %%
df['category'].head(100)
# Out:
# 0     Main Game
# 1     Main Game
# 2     Main Game
# 3     Main Game
# 4     Main Game
#         ...
# 95    Main Game
# 96    Main Game
# 97    Main Game
# 98    Main Game
# 99    Main Game
# Name: category, Length: 100, dtype: object

# %%
df
# Out:
#               id                                 name platforms  \
# 0         1020.0                      GrandTheftAutoV       NaN
# 1         1942.0                 TheWitcher3:WildHunt       NaN
# 2           72.0                              Portal2       NaN
# 3          472.0              TheElderScrollsV:Skyrim       NaN
# 4         1009.0                          TheLastofUs       NaN
# ...          ...                                  ...       ...
# 122397   36795.0                  SuperDoomed'nDamned       NaN
# 122398  114314.0                         DestleStrike       NaN
# 122399  115593.0                            NextStop3       NaN
# 122400  115038.0  \u5e7d\u94c3\u5170-lilyofthehollow-       NaN
# 122401   76632.0                            [accuwar]       NaN
#
#        first_release_date   category           genres  themes  \
# 0              2013-09-17  Main Game              NaN     NaN
# 1              2015-05-19  Main Game              NaN  Action
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122402 entries, 0 to 122401
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   id                         122401 non-null  float64
#  1   name                       122400 non-null  object
#  2   platforms                  0 non-null       object
#  3   first_release_date         64068 non-null   object
#  4   category                   122401 non-null  object
#  5   genres                     23 non-null      object
#  6   themes                     22 non-null      object
#  7   player_perspectives        7 non-null       object
#  8   rating                     18645 non-null   float64
#  9   rating_count               18648 non-null   float64
#  10  similar_games              87876 non-null   object
#  11  total_rating               18648 non-null   float64
#  12  total_rating_count         18648 non-null   float64
# ...

# %%
df.head()
# Out:
#        id                     name platforms first_release_date   category  \
# 0  1020.0          GrandTheftAutoV       NaN         2013-09-17  Main Game
# 1  1942.0     TheWitcher3:WildHunt       NaN         2015-05-19  Main Game
# 2    72.0                  Portal2       NaN         2011-04-19  Main Game
# 3   472.0  TheElderScrollsV:Skyrim       NaN         2011-11-11  Main Game
# 4  1009.0              TheLastofUs       NaN         2013-06-14  Main Game
#
#             genres  themes player_perspectives     rating  rating_count  \
# 0              NaN     NaN                 NaN  91.007003        2783.0
# 1              NaN  Action        First person  95.708657        2468.0
# 2  Point-and-click     NaN        Third person  91.331534        2116.0
# 3              NaN     NaN           Bird view  87.714979        2184.0
# 4         Fighting     NaN           Side view  94.494275        1835.0
#
#                                        similar_games  total_rating  \
# ...

# %%
df.tail()
# Out:
#               id                                 name platforms  \
# 122397   36795.0                  SuperDoomed'nDamned       NaN
# 122398  114314.0                         DestleStrike       NaN
# 122399  115593.0                            NextStop3       NaN
# 122400  115038.0  \u5e7d\u94c3\u5170-lilyofthehollow-       NaN
# 122401   76632.0                            [accuwar]       NaN
#
#        first_release_date   category genres themes player_perspectives  \
# 122397                NaN  Main Game    NaN    NaN                 NaN
# 122398                NaN  Main Game    NaN    NaN                 NaN
# 122399                NaN  Main Game    NaN    NaN                 NaN
# 122400                NaN  Main Game    NaN    NaN                 NaN
# 122401                NaN  Main Game    NaN    NaN                 NaN
#
#         rating  rating_count  \
# 122397     NaN           NaN
# 122398     NaN           NaN
# 122399     NaN           NaN
# ...

# %%
df.describe()
# Out:
#                   id        rating  rating_count  total_rating  \
# count  122401.000000  18645.000000  18648.000000  18648.000000
# mean    71442.522512     68.727962     23.332207     68.797717
# std     41101.619786     14.897546     96.058306     14.303439
# min         1.000000      0.000000      1.000000      0.000000
# 25%     37901.000000     60.000000      1.000000     60.000000
# 50%     71091.000000     70.000000      3.000000     70.145445
# 75%    107246.000000     80.000000     11.000000     79.988435
# max    141114.000000    100.000000   2783.000000    100.000000
#
#        total_rating_count  aggregated_rating  aggregated_rating_count  \
# count        18648.000000       12417.000000             12417.000000
# mean            25.549067          68.669364                 3.777080
# std             97.694489          16.275314                 4.214995
# min              1.000000           0.000000                 0.000000
# ...

# %%
df.groupby('year').count().sort_values('id', ascending = False)
# Out:
#           id  name  platforms  first_release_date  category  genres  themes  \
# year
# 2017.0  6571  6571          0                6571      6571       1       2
# 2016.0  4451  4451          0                4451      4451       1       2
# 2020.0  4443  4443          0                4443      4443       0       0
# 2018.0  3443  3443          0                3443      3443       0       2
# 2019.0  3216  3216          0                3216      3216       0       0
# 2015.0  3075  3075          0                3075      3075       1       2
# 2014.0  2408  2408          0                2408      2408       0       0
# 2013.0  2004  2004          0                2004      2004       2       1
# 2010.0  1765  1765          0                1765      1765       2       2
# 2011.0  1739  1739          0                1739      1739       2       1
# 2012.0  1677  1677          0                1677      1677       2       2
# ...

# %%
df.groupby('platforms').count().sort_values('id', ascending = False)
# Out:
# Empty DataFrame
# Columns: [id, name, first_release_date, category, genres, themes, player_perspectives, rating, rating_count, similar_games, total_rating, total_rating_count, url, aggregated_rating, aggregated_rating_count, year, month, weighted_score, normalized_weighted_score]
# Index: []

# %%
#df_count = df.groupby('year')['platforms'].apply(lambda x: (x=='PC').count()).reset_index(name='count')
#groupby year and count number of 'platforms' equal to 'PC'



df.groupby('year')['platforms'].apply(lambda x: (x=='PC').count()).reset_index(name='count')
# Out:
#       year  count
# 0   1970.0      2
# 1   1971.0      5
# 2   1972.0     26
# 3   1973.0     18
# 4   1974.0     16
# 5   1975.0     22
# 6   1976.0     42
# 7   1977.0     48
# 8   1978.0     69
# 9   1979.0     94
# 10  1980.0    154
# 11  1981.0    263
# 12  1982.0    515
# 13  1983.0    725
# 14  1984.0    566
# 15  1985.0    540
# 16  1986.0    700
# 17  1987.0    920
# 18  1988.0    822
# 19  1989.0    854
# 20  1990.0    936
# 21  1991.0    970
# 22  1992.0   1052
# 23  1993.0   1117
# 24  1994.0   1238
# 25  1995.0   1176
# 26  1996.0   1010
# 27  1997.0    892
# 28  1998.0    917
# 29  1999.0   1081
# 30  2000.0   1141
# 31  2001.0   1138
# 32  2002.0   1113
# 33  2003.0   1041
# 34  2004.0    997
# 35  2005.0   1078
# 36  2006.0   1201
# 37  2007.0   1182
# 38  2008.0   1365
# 39  2009.0   1638
# 40  2010.0   1765
# 41  2011.0   1739
# 42  2012.0   1677
# 43  2013.0   2004
# 44  2014.0   2408
# 45  2015.0   3075
# 46  2016.0   4451
# 47  2017.0   6571
# 48  2018.0   3443
# ...

# %%
##df.groupby(['continent']).apply(lambda x: x[x['Member_G20'] == 'Y' ]['GDP(trillion)'].sum())

#So we will first group by continent and then filter the rows in each group where a country is a G20 member


#df.groupby('year').apply(lambda x: x[x['platforms'] == 'PC'].sum())

# %%
#POK_Data[POK_Data['Name'].str.contains('^M')]

#foo[foo.b.str.contains('oo', regex= True, na=False)]

df[df['platforms'].str.contains('^PC', regex = True, na = False)]
# Out:
# Empty DataFrame
# Columns: [id, name, platforms, first_release_date, category, genres, themes, player_perspectives, rating, rating_count, similar_games, total_rating, total_rating_count, url, aggregated_rating, aggregated_rating_count, year, month, weighted_score, normalized_weighted_score]
# Index: []

# %%
result_PC = df[df['platforms'].str.contains('^PC', regex = True, na = False)]
result_PC
# Out:
# Empty DataFrame
# Columns: [id, name, platforms, first_release_date, category, genres, themes, player_perspectives, rating, rating_count, similar_games, total_rating, total_rating_count, url, aggregated_rating, aggregated_rating_count, year, month, weighted_score, normalized_weighted_score]
# Index: []

# %%
df[df['platforms'].str.contains('^Xbox', regex = True, na = False)]
# Out:
# Empty DataFrame
# Columns: [id, name, platforms, first_release_date, category, genres, themes, player_perspectives, rating, rating_count, similar_games, total_rating, total_rating_count, url, aggregated_rating, aggregated_rating_count, year, month, weighted_score, normalized_weighted_score]
# Index: []

# %%
result_xbox = df[df['platforms'].str.contains('^Xbox', regex = True, na = False)]
result_xbox
# Out:
# Empty DataFrame
# Columns: [id, name, platforms, first_release_date, category, genres, themes, player_perspectives, rating, rating_count, similar_games, total_rating, total_rating_count, url, aggregated_rating, aggregated_rating_count, year, month, weighted_score, normalized_weighted_score]
# Index: []

# %%
result_xbox.groupby('year').count()
# Out:
# Empty DataFrame
# Columns: [id, name, platforms, first_release_date, category, genres, themes, player_perspectives, rating, rating_count, similar_games, total_rating, total_rating_count, url, aggregated_rating, aggregated_rating_count, month, weighted_score, normalized_weighted_score]
# Index: []

# %%
result_play.groupby('year').count()
# Out:
#         id  name  platforms  first_release_date  category  genres  themes  \
# year
# 2004.0   1     1          1                   1         1       1       0
# 2005.0   1     1          1                   1         1       0       0
# 2006.0   1     1          1                   1         1       0       1
# 2007.0   1     1          1                   1         1       1       0
# 2010.0   1     1          1                   1         1       1       0
# 2011.0   1     1          1                   1         1       0       0
# 2012.0   1     1          1                   1         1       0       0
# 2018.0   1     1          1                   1         1       0       0
#
#         player_perspectives  rating  rating_count  similar_games  \
# year
# 2004.0                    1       1             1              1
# 2005.0                    0       1             1              1
# 2006.0                    0       1             1              1
# ...

# %%
result_PC.groupby('year').count()
# Out:
# Empty DataFrame
# Columns: [id, name, platforms, first_release_date, category, genres, themes, player_perspectives, rating, rating_count, similar_games, total_rating, total_rating_count, url, aggregated_rating, aggregated_rating_count, month, weighted_score, normalized_weighted_score]
# Index: []

# %%
result_play_4.groupby('year').count()
# Out:
#         id  name  platforms  first_release_date  category  genres  themes  \
# year
# 2012.0   1     1          1                   1         1       0       0
#
#         player_perspectives  rating  rating_count  similar_games  \
# year
# 2012.0                    0       1             1              1
#
#         total_rating  total_rating_count  url  aggregated_rating  \
# year
# 2012.0             1                   1    1                  1
#
#         aggregated_rating_count  month  weighted_score  \
# year
# 2012.0                        1      1               1
#
#         normalized_weighted_score
# year
# 2012.0                          1

# %%
#PlayStation

# %%
result_play = df[df['platforms'].str.contains('^PlayStation', regex = True, na = False)]
result_play
# Out:
# Empty DataFrame
# Columns: [id, name, platforms, first_release_date, category, genres, themes, player_perspectives, rating, rating_count, similar_games, total_rating, total_rating_count, url, aggregated_rating, aggregated_rating_count, year, month, weighted_score, normalized_weighted_score]
# Index: []

# %%
concat_frame = [result_play, result_xbox, ]
new_df = pd.concat(concat_frame)
new_df
# Out:
# Empty DataFrame
# Columns: [id, name, platforms, first_release_date, category, genres, themes, player_perspectives, rating, rating_count, similar_games, total_rating, total_rating_count, url, aggregated_rating, aggregated_rating_count, year, month, weighted_score, normalized_weighted_score]
# Index: []

# %%
result_play_4 = df[df['platforms'].str.contains('^PlayStation 4', regex = True, na = False)]
result_play_4
# Out:
# Empty DataFrame
# Columns: [id, name, platforms, first_release_date, category, genres, themes, player_perspectives, rating, rating_count, similar_games, total_rating, total_rating_count, url, aggregated_rating, aggregated_rating_count, year, month, weighted_score, normalized_weighted_score]
# Index: []

# %%
## Groupby multiple columns and aggregate on selected column
#result = df.groupby(['Courses','Fee'])['Courses'].count()

#df.groupby(['year', 'platforms'])['platforms'].count()

# %%
df.groupby(['year', 'platforms']).count()
# Out:
# Empty DataFrame
# Columns: [id, name, first_release_date, category, genres, themes, player_perspectives, rating, rating_count, similar_games, total_rating, total_rating_count, url, aggregated_rating, aggregated_rating_count, month, weighted_score, normalized_weighted_score]
# Index: []

# %% [markdown]
# # How many titles were released per year for each platform? (Tip: it makes sense to study the most recent platform versions that we have enough data for Main Game categories)

# %%
result = df.groupby('platforms').count().sort_values('id', ascending=False)
result
# Out:
# Empty DataFrame
# Columns: [id, name, first_release_date, category, genres, themes, player_perspectives, rating, rating_count, similar_games, total_rating, total_rating_count, url, aggregated_rating, aggregated_rating_count, year, month, weighted_score, normalized_weighted_score]
# Index: []

# %%
df[df['platforms'] == 'missing']
# Out:
# Empty DataFrame
# Columns: [id, name, platforms, first_release_date, category, genres, themes, player_perspectives, rating, rating_count, similar_games, total_rating, total_rating_count, url, aggregated_rating, aggregated_rating_count, year, month, weighted_score, normalized_weighted_score]
# Index: []

# %% [markdown]
# # Do game ratings vary from year to year for each of these platforms? And how?
